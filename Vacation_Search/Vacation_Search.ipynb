# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

from citipy import citipy
# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_df = pd.read_csv("../weather_data/WeatherPy_Database.csv")

# Display sample data
city_df.head()
# Out:
#    City_ID         City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0      Ushuaia      AR -54.8000  -68.3000     62.26        36
# 1        1       Barrow      US  71.2906 -156.7887    -11.18        77
# 2        2      Mataura      NZ -46.1927  168.8643     55.33        61
# 3        3  Clyde River      CA  70.4692  -68.5914    -28.97        75
# 4        4   Kaitangata      NZ -46.2817  169.8464     55.56        68
#
#    Cloudiness  Wind Speed       Description                 Date
# 0          40        9.22  scattered clouds  2023-01-07 19:25:23
# 1           0       13.80              mist  2023-01-07 19:30:25
# 2           1        4.56         clear sky  2023-01-07 19:30:20
# 3           0        3.44         clear sky  2023-01-07 19:30:42
# 4           0        8.81         clear sky  2023-01-07 19:31:53

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_df.loc[
    (city_df["Max Temp"] <= max_temp) & (city_df["Max Temp"] >= min_temp)
]

# Display sample data
preferred_cities_df.head(10)
# Out:
#     City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 6         6     Kavaratti      IN  10.5669   72.6420     81.14        64
# 7         7     Mount Isa      AU -20.7333  139.5000     73.17       100
# 9         9      Lorengau      PG  -2.0226  147.2712     80.56        78
# 15       15     Bathsheba      BB  13.2167  -59.5167     83.01        74
# 17       17  Mamallapuram      IN  12.6264   80.1722     78.85        80
# 20       20        Atuona      PF  -9.8000 -139.0333     78.01        77
# 24       24      Meulaboh      ID   4.1363   96.1285     74.75        87
# 25       25          Hilo      US  19.7297 -155.0900     76.24        69
# 27       27        Faanui      PF -16.4833 -151.7500     80.96        66
# 29       29  Puerto Ayora      EC  -0.7393  -90.3518     82.36        91
#
#     Cloudiness  Wind Speed                  Description                 Date
# 6            5        7.11                    clear sky  2023-01-07 19:33:46
# 7          100        5.75  light intensity shower rain  2023-01-07 19:31:06
# 9           99        3.91              overcast clouds  2023-01-07 19:31:12
# 15          40       17.27             scattered clouds  2023-01-07 19:31:15
# 17          19       10.29                   few clouds  2023-01-07 19:40:05
# 20          47       16.46                   light rain  2023-01-07 19:30:48
# 24         100        3.00              overcast clouds  2023-01-07 19:30:16
# 25          40        8.05             scattered clouds  2023-01-07 19:31:08
# 27          17        1.88                   few clouds  2023-01-07 19:32:43
# 29          21        7.00                   few clouds  2023-01-07 19:30:44

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
preferred_cities_df = preferred_cities_df.dropna()


# Display sample data
preferred_cities_df.head(10)
# Out:
#     City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 6         6     Kavaratti      IN  10.5669   72.6420     81.14        64
# 7         7     Mount Isa      AU -20.7333  139.5000     73.17       100
# 9         9      Lorengau      PG  -2.0226  147.2712     80.56        78
# 15       15     Bathsheba      BB  13.2167  -59.5167     83.01        74
# 17       17  Mamallapuram      IN  12.6264   80.1722     78.85        80
# 20       20        Atuona      PF  -9.8000 -139.0333     78.01        77
# 24       24      Meulaboh      ID   4.1363   96.1285     74.75        87
# 25       25          Hilo      US  19.7297 -155.0900     76.24        69
# 27       27        Faanui      PF -16.4833 -151.7500     80.96        66
# 29       29  Puerto Ayora      EC  -0.7393  -90.3518     82.36        91
#
#     Cloudiness  Wind Speed                  Description                 Date
# 6            5        7.11                    clear sky  2023-01-07 19:33:46
# 7          100        5.75  light intensity shower rain  2023-01-07 19:31:06
# 9           99        3.91              overcast clouds  2023-01-07 19:31:12
# 15          40       17.27             scattered clouds  2023-01-07 19:31:15
# 17          19       10.29                   few clouds  2023-01-07 19:40:05
# 20          47       16.46                   light rain  2023-01-07 19:30:48
# 24         100        3.00              overcast clouds  2023-01-07 19:30:16
# 25          40        8.05             scattered clouds  2023-01-07 19:31:08
# 27          17        1.88                   few clouds  2023-01-07 19:32:43
# 29          21        7.00                   few clouds  2023-01-07 19:30:44

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp","Description", "Lat", "Lng"]].copy()

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df["Hotel_Name"] = ""

# Display sample data
hotel_df.head(10)
len (hotel_df)
# Out:
# 219

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key,
    "filter": f"circle{longitude},{latitude},{radius}",
    "limit": 20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Print a message to follow up the hotel search
print("Starting hotel search")
# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"

    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    # Get the first hotel from the results and store the name
    try:
        hotel_df.loc[index, "Hotel_Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
    # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel_Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel_Name']}")
# Out:
# Starting hotel search
# Kavaratti - nearest hotel: No hotel found
# Mount Isa - nearest hotel: Ibis Styles
# Lorengau - nearest hotel: Seeadler Bay Hotel
# Bathsheba - nearest hotel: Clifton Hall Great House
# Mamallapuram - nearest hotel: Radisson Temple Bay
# Atuona - nearest hotel: Pearl Resort
# Meulaboh - nearest hotel: Hotel Meuligou
# Hilo - nearest hotel: Dolphin Bay Hotel
# Faanui - nearest hotel: Four Seasons Resort Bora Bora
# Puerto Ayora - nearest hotel: Muyuyo Galápagos
# Mahebourg - nearest hotel: Preskil Island Resort
# Kapaa - nearest hotel: Sheraton Kauai Coconut Beach Resort
# Katobu - nearest hotel: No hotel found
# Ambilobe - nearest hotel: Diagonal Hôtel
# Paramonga - nearest hotel: Hotel Rico
# Hithadhoo - nearest hotel: Pebbles Inn
# Buala - nearest hotel: No hotel found
# Kalmunai - nearest hotel: Sakkaryya Hotel and Restaurant
# Polewali - nearest hotel: hotel perdana
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Micheweni - nearest hotel: No hotel found
# Cape Town - nearest hotel: DoubleTree by Hilton Hotel Cape Town - Upper Eastside
# Vaini - nearest hotel: Keleti International Resort
# Port-Gentil - nearest hotel: Hôtel L'Hirondelle
# Butaritari - nearest hotel: No hotel found
# Georgetown - nearest hotel: Super 8
# Hambantota - nearest hotel: Peacock Beach hotel Hamabthota
# Souillac - nearest hotel: Hotel SkylineInn
# Kununurra - nearest hotel: ibis Styles Kununurra
# Sao Joao Da Barra - nearest hotel: Pousada Mediterrâneo
# Poum - nearest hotel: No hotel found
# Manta - nearest hotel: Mantahost Hotel
# Neiafu - nearest hotel: Port Wine Guest House
# Acarau - nearest hotel: No hotel found
# Bambanglipuro - nearest hotel: No hotel found
# Tevaitoa - nearest hotel: Raiatea Lodge
# Chuy - nearest hotel: Bertelli Chuí Hotel
# Ixtapa - nearest hotel: No hotel found
# Sinnamary - nearest hotel: L'Oiseau de Paradis - Hôtel Eco-Lodge
# Sabang - nearest hotel: Sabang Hill
# Pasni - nearest hotel: No hotel found
# Bengkulu - nearest hotel: Hotel Andalas Permai
# Cabedelo - nearest hotel: No hotel found
# Emerald - nearest hotel: Emerald Central Hotel
# Saint-Philippe - nearest hotel: Le Baril
# Frontera - nearest hotel: holliday in
# Maragogi - nearest hotel: Hotel Praia Dourada
# Vanimo - nearest hotel: Vanimo Surf Lodge
# Salalah - nearest hotel: Al Andalus Hotel Apartments
# Carnarvon - nearest hotel: No hotel found
# Touros - nearest hotel: Pousada Atlântico
# Kavieng - nearest hotel: Kavieng Niu Lodge
# Avarua - nearest hotel: Natura Nikao Beach Bungalow
# Imbituba - nearest hotel: Hotel Recanto
# Itarema - nearest hotel: Barraca Do Kite
# Thinadhoo - nearest hotel: No hotel found
# Coihueco - nearest hotel: No hotel found
# Menongue - nearest hotel: No hotel found
# Dingle - nearest hotel: No hotel found
# Coquimbo - nearest hotel: Hotel Liverpool
# Guerrero Negro - nearest hotel: Cabanas Malarrimo
# Quelimane - nearest hotel: Hotel Chuabo
# Chimbote - nearest hotel: Hotel "El Conquistador"
# Robstown - nearest hotel: Quality Inn & Suites
# Vao - nearest hotel: Nataiwatch
# George Town - nearest hotel: Super 8
# Ikom - nearest hotel: Gold Palm Hotels
# Grand-Santi - nearest hotel: No hotel found
# Rawson - nearest hotel: Hotel Punta León
# Labuhan - nearest hotel: No hotel found
# Anito - nearest hotel: No hotel found
# Copiapo - nearest hotel: PARIX
# Alugan - nearest hotel: No hotel found
# Alta Floresta - nearest hotel: Villas Hotel
# Mitsamiouli - nearest hotel: Maludja Bungalows
# Cidreira - nearest hotel: Hotel Castelo
# San Policarpo - nearest hotel: No hotel found
# Auki - nearest hotel: No hotel found
# Grajau - nearest hotel: Torre Palace Hotel
# Bambous Virieux - nearest hotel: No hotel found
# Buchanan - nearest hotel: Buchanan Hotel
# Puerto Baquerizo Moreno - nearest hotel: Miconia Hotel & Restaurant
# Jesus Carranza - nearest hotel: No hotel found
# Mitu - nearest hotel: No hotel found
# Biak - nearest hotel: No hotel found
# Port Blair - nearest hotel: Hornbill Nest resort
# Sibolga - nearest hotel: Hotel Hotma
# Owando - nearest hotel: Hotel de l'Eglise
# Sambava - nearest hotel: Orchidéa Beach II
# Olinda - nearest hotel: Pousada dos Quatro Cantos
# Tabou - nearest hotel: hôtel le rochet
# Cabo San Lucas - nearest hotel: Waldorf Astoria Los Cabos Pedregal
# Princeton - nearest hotel: No hotel found
# Aloleng - nearest hotel: No hotel found
# Basco - nearest hotel: Shanedels Inn and Cafe
# Bandar - nearest hotel: No hotel found
# Waingapu - nearest hotel: Hotel Jemmy
# Cabanas - nearest hotel: Vista Hermosa
# Padang - nearest hotel: Mercure Hotel
# San Patricio - nearest hotel: No hotel found
# Cazones - nearest hotel: No hotel found
# Cap Malheureux - nearest hotel: Hibiscus
# Manokwari - nearest hotel: Hotel Arfak
# Luanda - nearest hotel: Hotel Presidente Luanda
# Pisco - nearest hotel: Gran Hotel Chincha
# Sola - nearest hotel: No hotel found
# Port Hedland - nearest hotel: Hospitality Port Hedland
# Diamantino - nearest hotel: Hotel kayaby
# Bairiki - nearest hotel: Marry's Motel
# Kupang - nearest hotel: Sylvia Hotel
# Luganville - nearest hotel: Deco Stop Lodge
# Kahului - nearest hotel: Maui Seaside Hotel
# Lagos - nearest hotel: No hotel found
# Iracoubo - nearest hotel: No hotel found
# Porto Uniao - nearest hotel: Hotel Riad
# Sokoni - nearest hotel: La Madrugada Beach Hotel
# Koindu - nearest hotel: No hotel found
# Mineiros - nearest hotel: Hotel America
# Cornelio Procopio - nearest hotel: Hotel Midas
# Denpasar - nearest hotel: Hotel Pop! Teuku Umar Denpasar
# Manjacaze - nearest hotel: No hotel found
# Houma - nearest hotel: Holiday Inn Houma
# Sal Rei - nearest hotel: Riu Karamboa
# Oussouye - nearest hotel: Campement Emanaye
# Angoram - nearest hotel: No hotel found
# Bandarbeyla - nearest hotel: No hotel found
# Porto Velho - nearest hotel: Vilhema
# Noumea - nearest hotel: Hilton Noumea La Promenade Residences
# Trincomalee - nearest hotel: trinco rest house
# Jacareacanga - nearest hotel: Hotel São Cristovão
# Saint-Pierre - nearest hotel: Le Terre Sainte
# Les Cayes - nearest hotel: Hotel L jordin
# Vila Velha - nearest hotel: Hostess Hotel
# Aripuana - nearest hotel: No hotel found
# Cayenne - nearest hotel: Central Hôtel
# Batticaloa - nearest hotel: Bridge View Hotel
# Vila Do Maio - nearest hotel: Big Game Maio
# Harper - nearest hotel: No hotel found
# Kirando - nearest hotel: Lakeshore Lodge
# Bahia Honda - nearest hotel: No hotel found
# Iquique - nearest hotel: Hotel Terrado Suites
# Iquitos - nearest hotel: La Casa Fitzcarraldo
# Maun - nearest hotel: Center Lodge Conference Center
# Alibag - nearest hotel: Hira Laxmi Residency
# Sao Filipe - nearest hotel: Bela Vista
# Ambulu - nearest hotel: Hotel Ambulu
# Vaitape - nearest hotel: Conrad Bora Bora Nui
# Sorong - nearest hotel: Swiss-Belhotel
# Lantawan - nearest hotel: No hotel found
# Brandon - nearest hotel: Red Roof Inn - Brandon
# Ugoofaaru - nearest hotel: No hotel found
# Dwarka - nearest hotel: The Dwarika Hotel
# Ondjiva - nearest hotel: Villa Okapale
# Weligama - nearest hotel: Cape Weligama
# Kudahuvadhoo - nearest hotel: No hotel found
# Inhambane - nearest hotel: Casa Jensen
# Guiglo - nearest hotel: Hôtel Tam-Tam Annexe
# Sechura - nearest hotel: Grand Hotel Illescas
# Pitimbu - nearest hotel: Pitimbu Mar Hotel
# Jerez - nearest hotel: No hotel found
# Bol - nearest hotel: No hotel found
# Mogadishu - nearest hotel: Elite Hotel
# Lazaro Cardenas - nearest hotel: Quinta Antigua Hotel
# Tlaltenango - nearest hotel: No hotel found
# Edd - nearest hotel: No hotel found
# Natchez - nearest hotel: Holiday Inn Express Hotel & Suites Natchez South
# Mahanoro - nearest hotel: No hotel found
# Beloha - nearest hotel: No hotel found
# Kimbe - nearest hotel: Liamo Reef Resort
# Jacksonville - nearest hotel: Marriott Jacksonville Downtown
# Simbahan - nearest hotel: No hotel found
# Ati - nearest hotel: No hotel found
# Bac Lieu - nearest hotel: Nhà khách công đoàn
# Jizan - nearest hotel: No hotel found
# Ilebo - nearest hotel: Hôtel des Palmes
# Mont-Dore - nearest hotel: No hotel found
# Cape Canaveral - nearest hotel: Days Inn
# Grand Gaube - nearest hotel: Hotel Lux- Grand Gaube
# Aguililla - nearest hotel: No hotel found
# Panalingaan - nearest hotel: No hotel found
# Makakilo City - nearest hotel: Four Seasons O'ahu at Ko Olina
# Qandala - nearest hotel: No hotel found
# Puerto Madero - nearest hotel: No hotel found
# Santa Rosa - nearest hotel: Mariposa
# Mangochi - nearest hotel: Villa Tafika
# Raga - nearest hotel: No hotel found
# Tutoia - nearest hotel: Baluarte
# Marang - nearest hotel: Hotel Syahirah
# San Cristobal - nearest hotel: Nevada Suites
# Murud - nearest hotel: No hotel found
# Ruangwa - nearest hotel: No hotel found
# Amahai - nearest hotel: No hotel found
# Kloulklubed - nearest hotel: The Adventures Inn
# Bang Saphan - nearest hotel: Sailom Bangsaphan Resort
# Malakal - nearest hotel: No hotel found
# Celestun - nearest hotel: Hotel Maria del Carmen
# Carupano - nearest hotel: Hotel Los Molinos C.A
# Guaruja - nearest hotel: Casa Grande Hotel Resort And Spa Guaruja
# Takoradi - nearest hotel: Protea Hotel
# Balabac - nearest hotel: No hotel found
# Charters Towers - nearest hotel: No hotel found
# Massakory - nearest hotel: No hotel found
# Pangkalanbuun - nearest hotel: Arsela Hotel Pangkalan Bun
# The Valley - nearest hotel: La Vue
# Kendari - nearest hotel: Same Hotel Kendari
# Gamba - nearest hotel: No hotel found
# Luba - nearest hotel: Residencia Don Louis
# Huaquillas - nearest hotel: hotel orquídeas 2
# Springbok - nearest hotel: Hotel Springbok Inn
# Bourail - nearest hotel: Hôtel Restaurant La Néra
# Macaubas - nearest hotel: Macaúbas Palace Hotel
# Canutama - nearest hotel: No hotel found
# Pontianak - nearest hotel: Airy Pontianak Selatan Imam Bonjol 89
# Namibe - nearest hotel: IKA Hotel Namibe
# Mkokotoni - nearest hotel: No hotel found
# Karratha - nearest hotel: Karratha International Hotel
# San-Pedro - nearest hotel: Degny Plage Hôtel
# Morant Bay - nearest hotel: Golden Shore Resort
# Ahuimanu - nearest hotel: No hotel found

# %%
# Display sample data
len (hotel_df)
# Out:
# 219

# %%
hotel_df.head(20)
# Out:
#             City Country  Max Temp                  Description      Lat  \
# 6      Kavaratti      IN     81.14                    clear sky  10.5669
# 7      Mount Isa      AU     73.17  light intensity shower rain -20.7333
# 9       Lorengau      PG     80.56              overcast clouds  -2.0226
# 15     Bathsheba      BB     83.01             scattered clouds  13.2167
# 17  Mamallapuram      IN     78.85                   few clouds  12.6264
# 20        Atuona      PF     78.01                   light rain  -9.8000
# 24      Meulaboh      ID     74.75              overcast clouds   4.1363
# 25          Hilo      US     76.24             scattered clouds  19.7297
# 27        Faanui      PF     80.96                   few clouds -16.4833
# 29  Puerto Ayora      EC     82.36                   few clouds  -0.7393
# 32     Mahebourg      MU     79.25             scattered clouds -20.4081
# 33         Kapaa      US     74.10                   light rain  22.0752
# 40        Katobu      ID     74.50              overcast clouds  -4.9408
# 41      Ambilobe      MG     73.22              overcast clouds -13.2000
# 43     Paramonga      PE     74.08                    clear sky -10.6667
# 44     Hithadhoo      MV     79.86             scattered clouds  -0.6000
# 47         Buala      SB     81.61              overcast clouds  -8.1450
# 53      Kalmunai      LK     75.24              overcast clouds   7.4167
# 56      Polewali      ID     76.17              overcast clouds  -3.4324
# 57       Rikitea      PF     78.19                    clear sky -23.1203
#
#          Lng                           Hotel_Name
# 6    72.6420                       No hotel found
# 7   139.5000                          Ibis Styles
# 9   147.2712                   Seeadler Bay Hotel
# 15  -59.5167             Clifton Hall Great House
# 17   80.1722                  Radisson Temple Bay
# 20 -139.0333                         Pearl Resort
# 24   96.1285                       Hotel Meuligou
# 25 -155.0900                    Dolphin Bay Hotel
# 27 -151.7500        Four Seasons Resort Bora Bora
# 29  -90.3518                     Muyuyo Galápagos
# 32   57.7000                Preskil Island Resort
# 33 -159.3190  Sheraton Kauai Coconut Beach Resort
# 40  122.5276                       No hotel found
# 41   49.0500                       Diagonal Hôtel
# 43  -77.8333                           Hotel Rico
# 44   73.0833                          Pebbles Inn
# 47  159.5921                       No hotel found
# 53   81.8167       Sakkaryya Hotel and Restaurant
# 56  119.3435                        hotel perdana
# 57 -134.9692                 Chez Bianca & Benoit

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
no_hotel = hotel_df[hotel_df["Hotel_Name"] == "No hotel found"].index

hotel_df.drop(no_hotel, inplace = True)

# Display sample data
hotel_df.head(20)
# Out:
#             City Country  Max Temp                  Description      Lat  \
# 7      Mount Isa      AU     73.17  light intensity shower rain -20.7333
# 9       Lorengau      PG     80.56              overcast clouds  -2.0226
# 15     Bathsheba      BB     83.01             scattered clouds  13.2167
# 17  Mamallapuram      IN     78.85                   few clouds  12.6264
# 20        Atuona      PF     78.01                   light rain  -9.8000
# 24      Meulaboh      ID     74.75              overcast clouds   4.1363
# 25          Hilo      US     76.24             scattered clouds  19.7297
# 27        Faanui      PF     80.96                   few clouds -16.4833
# 29  Puerto Ayora      EC     82.36                   few clouds  -0.7393
# 32     Mahebourg      MU     79.25             scattered clouds -20.4081
# 33         Kapaa      US     74.10                   light rain  22.0752
# 41      Ambilobe      MG     73.22              overcast clouds -13.2000
# 43     Paramonga      PE     74.08                    clear sky -10.6667
# 44     Hithadhoo      MV     79.86             scattered clouds  -0.6000
# 53      Kalmunai      LK     75.24              overcast clouds   7.4167
# 56      Polewali      ID     76.17              overcast clouds  -3.4324
# 57       Rikitea      PF     78.19                    clear sky -23.1203
# 61     Cape Town      ZA     71.38                    clear sky -33.9258
# 64         Vaini      TO     82.56                broken clouds -21.2000
# 65   Port-Gentil      GA     78.76             scattered clouds  -0.7193
#
#          Lng                                         Hotel_Name
# 7   139.5000                                        Ibis Styles
# 9   147.2712                                 Seeadler Bay Hotel
# 15  -59.5167                           Clifton Hall Great House
# 17   80.1722                                Radisson Temple Bay
# 20 -139.0333                                       Pearl Resort
# 24   96.1285                                     Hotel Meuligou
# 25 -155.0900                                  Dolphin Bay Hotel
# 27 -151.7500                      Four Seasons Resort Bora Bora
# 29  -90.3518                                   Muyuyo Galápagos
# 32   57.7000                              Preskil Island Resort
# 33 -159.3190                Sheraton Kauai Coconut Beach Resort
# 41   49.0500                                     Diagonal Hôtel
# 43  -77.8333                                         Hotel Rico
# 44   73.0833                                        Pebbles Inn
# 53   81.8167                     Sakkaryya Hotel and Restaurant
# 56  119.3435                                      hotel perdana
# 57 -134.9692                               Chez Bianca & Benoit
# 61   18.4232  DoubleTree by Hilton Hotel Cape Town - Upper E...
# 64 -175.2000                        Keleti International Resort
# 65    8.7815                                 Hôtel L'Hirondelle

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"

# Export the City_Data into a csv
hotel_df.to_csv(output_data_file)

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 600,
    frame_height = 400,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["City", "Country","Description"]
)

# Display the map plot
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Country,Description)

# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
at_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
print (cities)
len (cities)
# Out:
# ['rikitea', 'sinegorye', 'airai', 'kargil', 'hobart', 'mattawa', 'todos santos', 'zonguldak', 'taolanaro', 'klaksvik', 'labuan', 'wajima', 'upernavik', 'galle', 'vaini', 'richmond', 'hermanus', 'nanortalik', 'atuona', 'geraldton', 'punta arenas', 'longyearbyen', 'mar del plata', 'mataura', 'abbeville', 'charqueadas', 'avarua', 'palabuhanratu', 'plettenberg bay', 'bolshegrivskoye', 'georgetown', 'jamestown', 'louisbourg', 'qaanaaq', 'codrington', 'cape town', 'barrow', 'corum', 'loubomo', 'koulamoutou', 'korla', 'norman wells', 'cidreira', 'choix', 'ushuaia', 'buritizeiro', 'thilogne', 'alofi', 'batagay', 'lorengau', 'dikson', 'vila velha', 'kumluca', 'chokurdakh', 'bambous virieux', 'nikolskoye', 'bethel', 'busselton', 'puerto ayora', 'illoqqortoormiut', 'victoria', 'matara', 'dzhebariki-khaya', 'isangel', 'constitucion', 'san juan', 'ilhabela', 'albany', 'san antonio', 'hay river', 'togur', 'royan', 'port alfred', 'leh', 'sao joao da barra', 'castro', 'kulhudhuffushi', 'ponta do sol', 'bluff', 'ikalamavony', 'lincoln', 'thunder bay', 'shimoda', 'hasaki', 'samusu', 'gravdal', 'namatanai', 'bredasdorp', 'grindavik', 'mahebourg', 'anadyr', 'chapais', 'jinxiang', 'jiuquan', 'pucara', 'saskylakh', 'vanavara', 'poyarkovo', 'salalah', 'pascagoula', 'koundara', 'khatanga', 'tsihombe', 'cambrils', 'felipe carrillo puerto', 'katsuura', 'clyde river', 'attawapiskat', 'gamba', 'atyrau', 'hit', 'marsh harbour', 'saldanha', 'balkanabat', 'ribeira grande', 'gizo', 'kodiak', 'mackay', 'harer', 'college', 'lavrentiya', 'arraial do cabo', 'faanui', 'lushunkou', 'kurikka', 'butaritari', 'kapaa', 'pangnirtung', 'vrangel', 'narsaq', 'yellowknife', 'new norfolk', 'fairbanks', 'kefamenanu', 'mehamn', 'warqla', 'elat', 'darhan', 'alice springs', 'conde', 'ruatoria', 'iqaluit', 'vardo', 'husavik', 'xixiang', 'bakel', 'labytnangi', 'acarau', 'kampene', 'grand gaube', 'porto novo', 'nome', 'palmer', 'severo-kurilsk', 'provideniya', 'krasnovishersk', 'inirida', 'tuktoyaktuk', 'ilulissat', 'souillac', 'luderitz', 'puerto ayacucho', 'rawatbhata', 'morondava', 'east london', 'zheleznodorozhnyy', 'tasiilaq', 'grand river south east', 'springbok', 'bengkulu', 'muzaffarabad', 'parabel', 'udachnyy', 'padang', 'shache', 'zlobin', 'hangu', 'ixtapa', 'yablonovo', 'lolua', 'belushya guba', 'buchanan', 'podosinovets', 'anloga', 'quatre cocos', 'minbu', 'dublyany', 'thompson', 'hartselle', 'hilo', 'mount isa', 'rosetta', 'paisley', 'alotau', 'vizinga', 'saint-philippe', 'port elizabeth', 'stepnyak', 'necochea', 'old town', 'santo antonio do monte', 'mogadishu', 'daura', 'cabo san lucas', 'santa ana', 'mount gambier', 'altay', 'kargasok', 'makakilo city', 'sao filipe', 'carnarvon', 'lompoc', 'solnechnyy', 'belaya gora', 'kon tum', 'lubango', 'puri', 'jejuri', 'bathsheba', 'vostok', 'acapulco', 'pevek', 'ambon', 'jatai', 'mys shmidta', 'saint george', 'lermontovka', 'portland', 'lebu', 'tessalit', 'torbay', 'taltal', 'la ronge', 'novouzensk', 'itarema', 'shenzhen', 'karratha', 'beringovskiy', 'soyo', 'aasiaat', 'kavieng', 'sokoni', 'phuket', 'chuy', 'marcona', 'svetlyy', 'puerto montt', 'sidvokodvo', 'tapes', 'camana', 'ballitoville', 'manono', 'dmitriyevskaya', 'lodwar', 'kurumkan', 'hellvik', 'praia da vitoria', 'hami', 'oranjemund', 'sheksna', 'amderma', 'ust-kamchatsk', 'broken hill', 'tiksi', 'sao desiderio', 'sainte-luce', 'hithadhoo', 'chicama', 'ugoofaaru', 'iranshahr', 'buala', 'aflu', 'atbasar', 'shubarkuduk', 'altar', 'charters towers', 'paamiut', 'vestmanna', 'vaitupu', 'lar gerd', 'fort nelson', 'umm lajj', 'port lincoln', 'puerto baquerizo moreno', 'sitka', 'camacha', 'talnakh', 'samfya', 'clarksburg', 'okha', 'vyartsilya', 'buenos aires', 'fortuna', 'kahului', 'atar', 'san lorenzo', 'great yarmouth', 'lagoa', 'xuddur', 'floro', 'beyneu', 'paita', 'vao', 'podyuga', 'rumphi', 'abu zabad', 'bolu', 'tarudant', 'goure', 'saleaula', 'bubanza', 'saint-francois', 'san policarpo', 'pradopolis', 'verkhnyaya toyma', 'inhumas', 'kayerkan', 'homer', 'cravo norte', ' ...
# 740

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desctiption = city_weather["main"]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | saint-amand-les-eaux
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | coxim
# Processing Record 6 of Set 1 | rascani
# Processing Record 7 of Set 1 | pisco
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | cockburn town
# Processing Record 12 of Set 1 | doha
# Processing Record 13 of Set 1 | mukdahan
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | kindersley
# Processing Record 18 of Set 1 | nishihara
# Processing Record 19 of Set 1 | salalah
# Processing Record 20 of Set 1 | fez
# Processing Record 21 of Set 1 | carstairs
# Processing Record 22 of Set 1 | faanui
# Processing Record 23 of Set 1 | mezhdurechensk
# Processing Record 24 of Set 1 | kieta
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | barentsburg
# Processing Record 27 of Set 1 | manokwari
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | longyearbyen
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | kegayli
# Processing Record 32 of Set 1 | norman wells
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | vardo
# Processing Record 35 of Set 1 | yuzhne
# Processing Record 36 of Set 1 | mocambique
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | benevides
# Processing Record 40 of Set 1 | kanigoro
# Processing Record 41 of Set 1 | dingle
# Processing Record 42 of Set 1 | asyut
# Processing Record 43 of Set 1 | hofn
# Processing Record 44 of Set 1 | yar-sale
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | palmer
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | gat
# Processing Record 49 of Set 1 | lorengau
# Processing Record 50 of Set 1 | ponta do sol
# Processing Record 1 of Set 2 | marathon
# Processing Record 2 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | khani
# Processing Record 5 of Set 2 | quatre cocos
# Processing Record 6 of Set 2 | rio das pedras
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | ust-maya
# Processing Record 10 of Set 2 | palu
# Processing Record 11 of Set 2 | xaltianguis
# Processing Record 12 of Set 2 | mazamari
# Processing Record 13 of Set 2 | ilulissat
# Processing Record 14 of Set 2 | chapais
# Processing Record 15 of Set 2 | olafsvik
# Processing Record 16 of Set 2 | viedma
# Processing Record 17 of Set 2 | mackay
# Processing Record 18 of Set 2 | crateus
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | sinnamary
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | luganville
# Processing Record 23 of Set 2 | fredericton
# Processing Record 24 of Set 2 | cayenne
# Processing Record 25 of Set 2 | keflavik
# Processing Record 26 of Set 2 | barabinsk
# Processing Record 27 of Set 2 | nouadhibou
# Processing Record 28 of Set 2 | north bend
# Processing Record 29 of Set 2 | east london
# Processing Record 30 of Set 2 | esmeraldas
# Processing Record 31 of Set 2 | dzaoudzi
# Processing Record 32 of Set 2 | torbay
# Processing Record 33 of Set 2 | san policarpo
# Processing Record 34 of Set 2 | makaha
# Processing Record 35 of Set 2 | arraias
# Processing Record 36 of Set 2 | collierville
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | taolanaro
# Processing Record 39 of Set 2 | berlevag
# Processing Record 40 of Set 2 | namatanai
# Processing Record 41 of Set 2 | hobart
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | souillac
# Processing Record 44 of Set 2 | kungurtug
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | broome
# Processing Record 47 of Set 2 | qaanaaq
# Processing Record 48 of Set 2 | saskylakh
# Processing Record 49 of Set 2 | trairi
# Processing Record 50 of Set 2 | hambantota
# Processing Record 1 of Set 3 | saleaula
# Processing Record 2 of Set 3 | faya
# Processing Record 3 of Set 3 | amderma
# Processing Record 4 of Set 3 | jinchengjiang
# Processing Record 5 of Set 3 | hermanus
# Processing Record 6 of Set 3 | lavrentiya
# Processing Record 7 of Set 3 | odweyne
# Processing Record 8 of Set 3 | amazar
# Processing Record 9 of Set 3 | avarua
# Processing Record 10 of Set 3 | mahebourg
# Processing Record 11 of Set 3 | dovbysh
# Processing Record 12 of Set 3 | isangel
# Processing Record 13 of Set 3 | batemans bay
# Processing Record 14 of Set 3 | louisbourg
# Processing Record 15 of Set 3 | esperance
# Processing Record 16 of Set 3 | semey
# Processing Record 17 of Set 3 | kodiak
# Processing Record 18 of Set 3 | santa maria da boa vista
# Processing Record 19 of Set 3 | bellevue
# Processing Record 20 of Set 3 | clyde river
# Processing Record 21 of Set 3 | cairns
# Processing Record 22 of Set 3 | tura
# Processing Record 23 of Set 3 | hobyo
# Processing Record 24 of Set 3 | vila velha
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | arraial do cabo
# Processing Record 27 of Set 3 | saint-francois
# Processing Record 28 of Set 3 | nambucca heads
# Processing Record 29 of Set 3 | jinxiang
# Processing Record 30 of Set 3 | vanimo
# Processing Record 31 of Set 3 | saint-philippe
# Processing Record 32 of Set 3 | hithadhoo
# Processing Record 33 of Set 3 | sakaiminato
# Processing Record 34 of Set 3 | bambous virieux
# Processing Record 35 of Set 3 | codrington
# Processing Record 36 of Set 3 | cidreira
# Processing Record 37 of Set 3 | maldonado
# Processing Record 38 of Set 3 | khatanga
# Processing Record 39 of Set 3 | dunedin
# Processing Record 40 of Set 3 | abeche
# Processing Record 41 of Set 3 | tumannyy
# Processing Record 42 of Set 3 | barrow
# Processing Record 43 of Set 3 | huarmey
# Processing Record 44 of Set 3 | mechernich
# Processing Record 45 of Set 3 | alyangula
# Processing Record 46 of Set 3 | shimoda
# Processing Record 47 of Set 3 | vaitupu
# Processing Record 48 of Set 3 | margate
# Processing Record 49 of Set 3 | wukari
# Processing Record 50 of Set 3 | utiroa
# Processing Record 1 of Set 4 | paamiut
# Processing Record 2 of Set 4 | tiksi
# Processing Record 3 of Set 4 | saint george
# Processing Record 4 of Set 4 | victoria
# Processing Record 5 of Set 4 | nanakuli
# Processing Record 6 of Set 4 | umzimvubu
# Processing Record 7 of Set 4 | bridlington
# Processing Record 8 of Set 4 | santo domingo
# Processing Record 9 of Set 4 | chuy
# Processing Record 10 of Set 4 | sao filipe
# Processing Record 11 of Set 4 | novyy urengoy
# Processing Record 12 of Set 4 | hervey bay
# Processing Record 13 of Set 4 | la ronge
# Processing Record 14 of Set 4 | tabiauea
# Processing Record 15 of Set 4 | samusu
# Processing Record 16 of Set 4 | nikolskoye
# Processing Record 17 of Set 4 | donskoye
# Processing Record 18 of Set 4 | selma
# Processing Record 19 of Set 4 | port lincoln
# Processing Record 20 of Set 4 | port macquarie
# Processing Record 21 of Set 4 | dutlwe
# Processing Record 22 of Set 4 | verkhnevilyuysk
# Processing Record 23 of Set 4 | nizhneyansk
# Processing Record 24 of Set 4 | belushya guba
# Processing Record 25 of Set 4 | buin
# Processing Record 26 of Set 4 | evanston
# Processing Record 27 of Set 4 | luanda
# Processing Record 28 of Set 4 | touros
# Processing Record 29 of Set 4 | troitsko-pechorsk
# Processing Record 30 of Set 4 | mar del plata
# Processing Record 31 of Set 4 | pevek
# Processing Record 32 of Set 4 | belleville
# Processing Record 33 of Set 4 | gambissara
# Processing Record 34 of Set 4 | chernyshevskiy
# Processing Record 35 of Set 4 | hailar
# Processing Record 36 of Set 4 | nemuro
# Processing Record 37 of Set 4 | zaltan
# Processing Record 38 of Set 4 | grand gaube
# Processing Record 39 of Set 4 | tsihombe
# Processing Record 40 of Set 4 | husavik
# Processing Record 41 of Set 4 | burica
# Processing Record 42 of Set 4 | sakakah
# Processing Record 43 of Set 4 | puerto ayora
# Processing Record 44 of Set 4 | ourem
# Processing Record 45 of Set 4 | vila franca do campo
# Processing Record 46 of Set 4 | mandera
# Processing Record 47 of Set 4 | cabo san lucas
# Processing Record 48 of Set 4 | whitehorse
# Processing Record 49 of Set 4 | hami
# Processing Record 50 of Set 4 | geraldton
# Processing Record 1 of Set 5 | agadez
# Processing Record 2 of Set 5 | konakovo
# Processing Record 3 of Set 5 | souris
# Processing Record 4 of Set 5 | severo-kurilsk
# Processing Record 5 of Set 5 | sabang
# Processing Record 6 of Set 5 | gualaquiza
# Processing Record 7 of Set 5 | leningradskiy
# Processing Record 8 of Set 5 | ribeira grande
# Processing Record 9 of Set 5 | te kauwhata
# Processing Record 10 of Set 5 | arrecife
# Processing Record 11 of Set 5 | iwaki
# Processing Record 12 of Set 5 | port hedland
# Processing Record 13 of Set 5 | fort frances
# Processing Record 14 of Set 5 | noumea
# Processing Record 15 of Set 5 | malatya
# Processing Record 16 of Set 5 | natalio
# Processing Record 17 of Set 5 | longlac
# Processing Record 18 of Set 5 | bilibino
# Processing Record 19 of Set 5 | rabo de peixe
# Processing Record 20 of Set 5 | port hardy
# Processing Record 21 of Set 5 | beringovskiy
# Processing Record 22 of Set 5 | oktyabrskoye
# Processing Record 23 of Set 5 | golpayegan
# Processing Record 24 of Set 5 | boende
# Processing Record 25 of Set 5 | boa vista
# Processing Record 26 of Set 5 | yulara
# Processing Record 27 of Set 5 | nanortalik
# Processing Record 28 of Set 5 | george
# Processing Record 29 of Set 5 | saint-ambroise
# Processing Record 30 of Set 5 | georgetown
# Processing Record 31 of Set 5 | bull savanna
# Processing Record 32 of Set 5 | labuhan
# Processing Record 33 of Set 5 | tabou
# Processing Record 34 of Set 5 | seoul
# Processing Record 35 of Set 5 | bonfim
# Processing Record 36 of Set 5 | libreville
# Processing Record 37 of Set 5 | tecoanapa
# Processing Record 38 of Set 5 | sosnovo-ozerskoye
# Processing Record 39 of Set 5 | micheweni
# Processing Record 40 of Set 5 | meulaboh
# Processing Record 41 of Set 5 | esna
# Processing Record 42 of Set 5 | ruatoria
# Processing Record 43 of Set 5 | inhambane
# Processing Record 44 of Set 5 | itoigawa
# Processing Record 45 of Set 5 | guisa
# Processing Record 46 of Set 5 | grand river south east
# Processing Record 47 of Set 5 | kahului
# Processing Record 48 of Set 5 | kousseri
# Processing Record 49 of Set 5 | taybad
# Processing Record 50 of Set 5 | cagayan de tawi-tawi
# Processing Record 1 of Set 6 | macaboboni
# Processing Record 2 of Set 6 | sitka
# Processing Record 3 of Set 6 | marsa matruh
# Processing Record 4 of Set 6 | buraydah
# Processing Record 5 of Set 6 | zemio
# Processing Record 6 of Set 6 | arkhangelsk
# Processing Record 7 of Set 6 | half moon bay
# Processing Record 8 of Set 6 | klyuchi
# Processing Record 9 of Set 6 | afmadu
# Processing Record 10 of Set 6 | lianzhou
# Processing Record 11 of Set 6 | wagar
# Processing Record 12 of Set 6 | samarai
# Processing Record 13 of Set 6 | libertador general san martin
# Processing Record 14 of Set 6 | sao jose da coroa grande
# Processing Record 15 of Set 6 | ust-kut
# Processing Record 16 of Set 6 | chase
# Processing Record 17 of Set 6 | kavieng
# Processing Record 18 of Set 6 | vostok
# Processing Record 19 of Set 6 | baykit
# Processing Record 20 of Set 6 | reykjavik
# Processing Record 21 of Set 6 | jiuquan
# Processing Record 22 of Set 6 | mingshui
# Processing Record 23 of Set 6 | santa cruz
# Processing Record 24 of Set 6 | cherskiy
# Processing Record 25 of Set 6 | asau
# Processing Record 26 of Set 6 | mtwara
# Processing Record 27 of Set 6 | wellington
# Processing Record 28 of Set 6 | nongstoin
# Processing Record 29 of Set 6 | shenjiamen
# Processing Record 30 of Set 6 | port elizabeth
# Processing Record 31 of Set 6 | ostrovnoy
# Processing Record 32 of Set 6 | nuuk
# Processing Record 33 of Set 6 | manoel urbano
# Processing Record 34 of Set 6 | ustyuzhna
# Processing Record 35 of Set 6 | svetlogorsk
# Processing Record 36 of Set 6 | grindavik
# Processing Record 37 of Set 6 | orotukan
# Processing Record 38 of Set 6 | riaba
# Processing Record 39 of Set 6 | illoqqortoormiut
# Processing Record 40 of Set 6 | chokurdakh
# Processing Record 41 of Set 6 | airai
# Processing Record 42 of Set 6 | soligalich
# Processing Record 43 of Set 6 | san pedro
# Processing Record 44 of Set 6 | tessaoua
# Processing Record 45 of Set 6 | alofi
# Processing Record 46 of Set 6 | coquimbo
# Processing Record 47 of Set 6 | puerto escondido
# Processing Record 48 of Set 6 | bethel
# Processing Record 49 of Set 6 | bonavista
# Processing Record 50 of Set 6 | kuah
# Processing Record 1 of Set 7 | maharajganj
# Processing Record 2 of Set 7 | san andres
# City not found. Skipping...
# Processing Record 3 of Set 7 | estevan
# Processing Record 4 of Set 7 | fonte boa
# Processing Record 5 of Set 7 | brae
# Processing Record 6 of Set 7 | dikson
# Processing Record 7 of Set 7 | solovetskiy
# Processing Record 8 of Set 7 | muisne
# Processing Record 9 of Set 7 | sirfa
# Processing Record 10 of Set 7 | datong
# Processing Record 11 of Set 7 | fortuna
# Processing Record 12 of Set 7 | kamenskoye
# Processing Record 13 of Set 7 | itacurubi del rosario
# Processing Record 14 of Set 7 | kotturu
# Processing Record 15 of Set 7 | bageshwar
# Processing Record 16 of Set 7 | voi
# Processing Record 17 of Set 7 | malayal
# Processing Record 18 of Set 7 | nioro
# Processing Record 19 of Set 7 | kavaratti
# Processing Record 20 of Set 7 | karaul
# Processing Record 21 of Set 7 | rosarito
# Processing Record 22 of Set 7 | cap malheureux
# Processing Record 23 of Set 7 | banda aceh
# Processing Record 24 of Set 7 | acapulco
# Processing Record 25 of Set 7 | santander jimenez
# Processing Record 26 of Set 7 | poum
# Processing Record 27 of Set 7 | batagay-alyta

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 691

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0            Bluff -46.6000  168.3333     56.80          few clouds        68
# 1            Metro  -5.1131  105.3067     88.48     overcast clouds        54
# 2    Pacific Grove  36.6177 -121.9166     64.08           clear sky        87
# 3     Saint George  37.1041 -113.5841     79.95           clear sky        40
# 4          Mataura -46.1927  168.8643     56.48          few clouds        56
# 5          Biltine  14.5333   20.9167     80.42    scattered clouds        61
# 6              Gao  16.6362    1.6370     85.73       broken clouds        47
# 7        Hithadhoo  -0.6000   73.0833     82.00    scattered clouds        72
# 8  Bambous Virieux -20.3428   57.7575     76.21       broken clouds        78
# 9          Rikitea -23.1203 -134.9692     73.35           clear sky        72
#
#    Cloudiness  Wind Speed Country
# 0          21        2.28      NZ
# 1          92        4.52      ID
# 2           0        4.61      US
# 3           0       10.36      US
# 4          15        2.44      NZ
# 5          27        3.36      TD
# 6          77        6.31      ML
# 7          47        7.78      MV
# 8          75       13.80      MU
# 9           3       14.23      PF

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = city_data_df.columns.tolist()
new_column_order =["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
new_column_order


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]


# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bluff      NZ -46.6000  168.3333     56.80        68          21
# 1            Metro      ID  -5.1131  105.3067     88.48        54          92
# 2    Pacific Grove      US  36.6177 -121.9166     64.08        87           0
# 3     Saint George      US  37.1041 -113.5841     79.95        40           0
# 4          Mataura      NZ -46.1927  168.8643     56.48        56          15
# 5          Biltine      TD  14.5333   20.9167     80.42        61          27
# 6              Gao      ML  16.6362    1.6370     85.73        47          77
# 7        Hithadhoo      MV  -0.6000   73.0833     82.00        72          47
# 8  Bambous Virieux      MU -20.3428   57.7575     76.21        78          75
# 9          Rikitea      PF -23.1203 -134.9692     73.35        72           3
#
#    Wind Speed Current Description
# 0        2.28          few clouds
# 1        4.52     overcast clouds
# 2        4.61           clear sky
# 3       10.36           clear sky
# 4        2.44          few clouds
# 5        3.36    scattered clouds
# 6        6.31       broken clouds
# 7        7.78    scattered clouds
# 8       13.80       broken clouds
# 9       14.23           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
